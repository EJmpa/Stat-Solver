# %% [markdown]
# ## Introduction

# %% [markdown]
# ## Questions
# - **What payment currency is mostly common among employees**
# - **Which level of education is common among people**
# - **What is the chance of getting a full time jon through NYSC placement?**
# - **What job level awaits a fresh graduate of high level education**
# - **What job role is common among employees?**
# - **What company sector/industry employ the people the most**
# - **What is the distribution of monthly income of fresh graduates**
# - **How essential is a formal education in getting a job**
# - **What is the range of work hours of employees?**
# - **Does Gender have effect on employment status?**
# - **Is there a relationship between year of graduation and employment status?**
# - **Which companies provide job opportunities for graduates the most?**
# - **What is the most common level of education**

# %% [markdown]
# ### Question 1: What payment currency is mostly common among employees?
# **Analysis shows about 98% of the employed were being paid in Naira(Nigeria currency)**

# %% [markdown]
# ![download1.png](attachment:download1.png)

# %% [markdown]
# ### Question 2 What level of education is common among people?
# **The highest level of education of most of the employees is Bachelor's degree as over 80% of them holds bachelor degree. PhDs/Doctorate is the least common**

# %% [markdown]
# ![download2.png](attachment:download2.png)

# %% [markdown]
# ### Question 3: What is the chance of getting a full time job through NYSC placement
# **Only about 15% of the employees got their job through NYSC placement and about 68% didn't.This indicates that the chance of getting a full time job through NYSC placement is generally low**

# %% [markdown]
# ![download3.png](attachment:download3.png)

# %% [markdown]
# ### Question 4: What job level awaits a fresh graduate of high level education
# **It can be seen from the chart below that majority of the fresh graduates(about 69%) started their career in an entry level position**

# %% [markdown]
# ![download4.png](attachment:download4.png)

# %% [markdown]
# ### Question 5: What job role is common among employees?
# **Teaching and Customer service appears the most popular roles as that was the job role of over 25% of the employees?**

# %% [markdown]
# ![download5.png](attachment:download5.png)

# %% [markdown]
# ### Question 6: What company sector/industry offers the highest job opportunites?
# **Analysis reveals that Education and Banking/Financial services sectors employs the most.This bests explain why the most common job roles are teaching and customer service**

# %% [markdown]
# ![download6.png](attachment:download6.png)

# %% [markdown]
# ### Question 7: What is the distribution of monthly income of fresh graduates?
# **It is observed that the salary range of most fresh graduates is between 20,000 and 100,000 and only about 2% of fresh graduates got a salary of 250,000 and above**

# %% [markdown]
# ![download7.png](attachment:download7.png)

# %% [markdown]
# ### Question 8: How essential is a formal education in getting a job
# **It can be deduced that over 50% of the job roles requires formal education and about 18% of the employed graduates claimed formal education gave them an advantage despite not being part of the requirements. This implies that a formal education is essential in getting a good job**

# %% [markdown]
# ![download8.png](attachment:download8.png)

# %% [markdown]
# ### Question 9: What is the range of work hours of employees?
# **Most of the employees work for about 8-10 hours daily**

# %% [markdown]
# ![download9.png](attachment:download9.png)

# %% [markdown]
# ### Question 10: Does Gender have effect on employment status?
# **About 36% of the females were unemployed and about 32% of males were unemployed. Since there isn't much significant difference between the employed and unemployed ratio of male and female,we can't conclude that gender has an effect on employment status**

# %% [markdown]
# ![download10.png](attachment:download10.png)
